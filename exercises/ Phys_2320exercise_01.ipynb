# %% [markdown]
# <a href="https://colab.research.google.com/github/jamunozlab/introductory_mechanics_spring_2023/blob/main/exercises/%20Phys_2320exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instructions
#
# 1.   Watch [this video](https://youtu.be/RLYoEyIHL6A) to learn the basic functionality that you need to get out of Google Colab for now.
# 2.   Review the notebook we used for discussion in lecture 2, it is available [here](https://github.com/jamunozlab/introductory_mechanics_fall_2022/blob/main/lecture_notebooks/Ph_2320_W1L2.ipynb). If you click on the "Open in Colab" icon you will be able to run/edit the code. Follow the instructions to get a Colab account if you don't already have one.
# 3. Open this code in Colab by clicking on the "Open in Colab" icon on this page. The snapshot below shows you where you should see the icon.

# %% [markdown]
# ![OpenColab.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# You do not need to know anything about pandas right now, we are only using it in this Notebook to make plotting your numbers very easy. For now, you can think about it as a very powerful Excel. I found this [this video](https://youtu.be/S8wO4ppE9L8) interesting.

# %%
# In class, we created a position vs time plot using the following numbers
# Evalute this cell!

time =     [0 , 1 ,  2,  3,  4, 5  ] # Let's say these are seconds
position = [0 , -2, -4, -6, -8, -10] # Let's say these are meters

# // This code cell defines TWO(2) user-defined VARIABLES named "time" and "Position",
# Each of these two(2) variables contain an ARRAY of six(6) ELEMENTS that hold the VALUES defined above.//

# %%
# Then we instructed the computer to create the plot using the following commands:

pretty_plot = pd.Series(position, index=time)                         # The keyword "pd.series()"" requires the names of the array variables that we wish to graph.
pretty_plot.plot(xlabel='time (seconds)', ylabel='position (meters)') # The keyword ".plot()" requires that we label both the axes of our graph.

# // This code cell uses Pandas' pre-defined funtions to output a graphical representation of the data contained in our variables "time" and "position". //

# %%
# The average velocity between 0 and 5 seconds is:

velocity = ( (-10) - (0) ) / ( (5) - (0) )               # // User defined variable named "velocity" is created and defined as an equation 
print('Average velocity is:', velocity, 'meters/second') # using values manually copied from the ARRAY VARIABLES defined above
                                                         #Remember that average velocity can be represented by the equation  [(pf - pi) / (tf - ti)] //
# Out:
# Average velocity is: -2.0 meters/second

# %%
# If you are lazy like me, grab the number in the appropriate ELEMENT POSITIONS rather than writing it down manually. 

velocity = ( position[5] - position[0] ) / ( time[5] - time[0] )
print('Average velocity is:', velocity, 'meters/second')          

# // Here, the variable "velocity" is calulated the same as it was in the previous cell.
# However, instead of typing the values from the array variables "time" and "position" manually,
# This cell directly pulls specific values from our array variables using "index positions" //
# Out:
# Average velocity is: -2.0 meters/second

# %% [markdown]
# # Exercise 1
#
# First, make sure you have evaluated (shift + enter) the cells above.
# In particular, you need to evaluate the pandas one to make sure that you call this package, which we are using to create the plot.
#
# COMPLETE THE MISSING PORTION OF THE CODE CELL BELOW. Let the first element in the variable named "position" be negative six (-6), then come up with a series of five(5) more numbers that will result in the generation of a "position vs time graph"  that appears as a strait line going up (positive slope).
#
#  Feel free to modify the cells below as many times as you want, you can refresh the results by clicking shift + enter each time. Answer the following:
#
# 1. What is the value of the position at time = 0 seconds?
# 2. What is the difference (final minus initial) between contiguous positions?
# 3. What is the average velocity?

# %%
time =     [0 , 1 ,  2,  3,  4, 5  ] # Don't change this one
position = [-6 , , , , , ] # CHANGE THIS ONE

# %%
# Evaluate this cell AFTER MAKING CHANGES to the "position values" above, to see how the new plot looks.
# // Remember the goal is to propigate a graph that displays a positive slope.//

pretty_plot = pd.Series(position, index=time)
pretty_plot.plot(xlabel='time (seconds)', ylabel='position (meters)')

# %%
# Evaluate this cell (shift + enter) for the computer to tell you what the
# average velocity between 0 seconds (the zeroth element in the array above)
# and 5 seconds (the sixth element in the array above)

velocity = ( position[5] - position[0] ) / ( time[5] - time[0] )
print('Average velocity is:', velocity, 'meters/second')
# Out:
# Average velocity is: -2.0 meters/second

# %% [markdown]
# # Exercise 2
#
# For this exercise, copy the relavent code from the cells above to make in order to propigate a new graph that meets the parameters specified below.
#
# As in the previous exercise; Without changing any of the numbers the "time" list, make the first number in the "position" list negative six (-6), and come up with a list of six numbers such that the position vs time plot is concave up curve (exponential increase).
#
# Then, using the dataset and graph that you've created to Answer the following:
#
# 1. What is the difference (final minus initial) between contiguous positions?
# 2. How is this different that previous case?
#
# #? contiguous: "Next or together in a series"/ sharing a common border or touching. ##?
